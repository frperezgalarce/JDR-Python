# %% [markdown]
# # Folded JDR validation — deterministic small set
#
# Version 2. Weighted period estimation, fitted phase alignment, ID-aligned scores and frequency-grid convergence. This is an in-sample smoke comparison, not held-out performance. Original observations are never overwritten.

# %%
from pathlib import Path
import sys
ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'src' / 'jdr.py').exists())
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
import numpy as np
import pandas as pd

# %%
from src.experiment import run_small_experiment
report = run_small_experiment(n_files=18, seed=42, output_dir=ROOT / 'results' / 'notebook_experiment4')
assert report['grid_relative_max_error'] < 1e-3
assert report['nearest_neighbors_unchanged']
pd.DataFrame(report['models']).T[['coverage', 'ari_all', 'ami_all', 'purity_assigned', 'n_clusters', 'n_noise']]
# Out:
#                  coverage   ari_all   ami_all purity_assigned n_clusters  \
# kmedoids              1.0  0.513933  0.534381        0.888889          3
# dbscan           0.833333  0.751713  0.679221             1.0          2
# hdbscan               1.0  0.697082  0.635319        0.888889          2
# average_linkage       1.0  0.811973  0.775496        0.944444          3
#
#                 n_noise
# kmedoids              0
# dbscan                3
# hdbscan               0
# average_linkage       0
