# %% [markdown]
# # Spectral regression checks
#
# Version 2. Independent quadrature must converge; failed integration raises rather than being hidden.

# %%
from pathlib import Path
import sys
ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / 'src' / 'jdr.py').exists())
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
import numpy as np
import pandas as pd

# %%
from src.metrics import spectral_coefficients, integrate_cross_spectrum_real, tau
from src.jdr import JDRConfig, feature_vector
rng = np.random.default_rng(42)
t = np.sort(rng.uniform(0, 4, 60))
x = np.sin(2*np.pi*0.7*t)
y = np.sin(2*np.pi*0.7*t+0.3)
config = JDRConfig(f_min=0.3, f_max=1.0, n_frequencies=2049)
zx, zy = feature_vector(t,x,config), feature_vector(t,y,config)
J_grid = float(np.dot(zx-zy,zx-zy))
Ix = integrate_cross_spectrum_real(.3,1.,t,x,t,x)
Iy = integrate_cross_spectrum_real(.3,1.,t,y,t,y)
Ixy = integrate_cross_spectrum_real(.3,1.,t,x,t,y)
J_quad = .25/(2*np.pi)*(Ix+Iy-2*Ixy)
assert np.isclose(J_grid,J_quad,rtol=1e-5)
{'grid': J_grid, 'converged_quadrature': J_quad}
# Out:
# {'grid': 0.0008462251484676461, 'converged_quadrature': 0.0008462251385415117}

# %%
w = 1.7
shift = tau(t,w)
assert abs(np.sum(np.sin(w*(t-shift))*np.cos(w*(t-shift)))) < 1e-12
assert np.allclose(feature_vector(t,3*x+20,config),zx)
